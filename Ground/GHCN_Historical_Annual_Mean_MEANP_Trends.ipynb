# %%
# %reset -f

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import requests
from datetime import datetime as dt
from datetime import timedelta
import shutil
import os
import scipy as scipy
import statsmodels.api as sm

stationIDLINK = 'https://www.ncei.noaa.gov/pub/data/ghcn/daily/ghcnd-stations.txt'
metadataLINK = 'https://www.ncei.noaa.gov/pub/data/ghcn/daily/ghcnd-inventory.txt'
dataLINK = 'https://www.ncei.noaa.gov/data/global-historical-climatology-network-daily/access'
outFILE = '/content/drive/My Drive/Colab Notebooks/GHCN_Historical_Annual_Mean_MEANP_Trends_Results.csv'
dataFILE = '/content/drive/My Drive/Colab Notebooks/GHCN_Historical_Annual_Mean_MEANP_Trends_Data.csv'

url = stationIDLINK
req = requests.get(url)
text = req.text

keepers_step_one = []
lines = (line for line in text.splitlines())
for line in lines:
  row = line.split()
  stationID = row[0]
  if stationID[:2] == 'US':
    state = row[4]
    if state in ['AZ', 'NM', 'NV', 'UT']:
      keepers_step_one.append(stationID)

url = metadataLINK
req = requests.get(url)
text = req.text

keepers_step_two = []
lines = (line for line in text.splitlines())
for line in lines:
  row = line.split()
  if 'PRCP' in row and row[0] in keepers_step_one:
    if int(row[4]) <= 1974 and int(row[5]) >= 2013:
      keepers_step_two.append(row[0])

dates = []
start_date = dt(1974, 1, 1, 0, 0)
end_date = dt(2013, 12, 31, 0, 0)
date = start_date
while date < end_date:
  dates.append(date)
  date = date + timedelta(days=1)

#No html address
bad = []
for keeper in keepers_step_two:
  ct = 0
  url = dataLINK + '/' + keeper + '.csv'
  req = requests.get(url)
  text = req.text
  if not '404 Not Found' in text:
    ct = 0
    lines = [line for line in text.splitlines()]
    save_lines = []
    hdrs = lines[0].split(',')
    prcp_i = hdrs.index('"PRCP"')
    date_i = hdrs.index('"DATE"')
    for line in lines[1:]:
      row = line.split('","')
      name_no_comma = row[5].replace(',', '')
      line = line.replace(row[5], name_no_comma)
      line = line.replace('","', ',')
      row = line.split(',')
      date = dt.strptime(row[date_i].strip('"'), '%Y-%m-%d')
      prcp = row[prcp_i].strip('"')
      if date.year >= 1974 and date.year <= 2013:
        if prcp != '' and not any([s in prcp for s in ['P', 'T', 'H', '9999']]):
          prcp = float(prcp)
          ct += 1

    if float(ct)/float(len(dates))*100. < 98.:
      print(str(float(ct)/float(len(dates))*100))
      bad.append(keeper)

  else:
    bad.append(keeper)

keepers_step_three = [k for k in keepers_step_two if k not in bad]
keepers = keepers_step_three



#DATA ANALYSIS



data_df = pd.DataFrame()
i = 0
done = False
save_data = []
while done == False:
  keeper = keepers[i]
  print(keeper)

  try:
    url = dataLINK + '/' + keeper + '.csv'
    req = requests.get(url)
    text = req.text

    data_dict = {'date':[], 'precip':[]}
    lines = [line for line in text.splitlines()]
    hdrs = lines[0].split(',')
    prcp_i = hdrs.index('"PRCP"')
    date_i = hdrs.index('"DATE"')
    for line in lines[1:]:
      row = line.split('","')
      name_no_comma = row[5].replace(',', '')
      line = line.replace(row[5], name_no_comma)
      line = line.replace('","', ',')
      row = line.split(',')
      lon = row[3]
      lat = row[2]
      date = dt.strptime(row[date_i].strip('"'), '%Y-%m-%d')
      prcp = row[prcp_i].strip('"')
      if date.year >= 1974 and date.year <= 2013:
        if prcp != '' and not any([s in prcp for s in ['P', 'T', 'H', '9999']]):
          prcp = float(prcp)/10.
        else:
          prcp = 0.

        if prcp > 0.:
          data_dict['date'].append(date)
          data_dict['precip'].append(prcp)

    df = pd.DataFrame(data=data_dict)

    def get_yr(d):
      yr = d.year
      return yr

    df['year'] = df['date'].apply(get_yr)

    def get_mo(d):
      mo = d.month
      return mo

    df['month'] = df['date'].apply(get_mo)
    means = df.groupby('year')['precip'].mean()
    sdevs = df.groupby('year')['precip'].std()
    skews = df.groupby('year')['precip'].skew()

    x = np.arange(0, 40)
    X = sm.add_constant(x)

    model = sm.OLS(means, X)
    results = model.fit()
    slope_means = results.params[1]

    model = sm.OLS(sdevs, X)
    results = model.fit()
    slope_sdevs = results.params[1]

    model = sm.OLS(skews, X)
    results = model.fit()
    slope_skews = results.params[1]

    mean = df['precip'].mean()
    sdev = df['precip'].std()
    skew = df['precip'].skew()

    save_data.append([keeper, lon, lat, str(slope_means), str(mean), str(slope_sdevs), str(sdev), str(slope_skews), str(skew)])

    i += 1

    data_df[keeper + '_means'] = means
    data_df[keeper + '_sdevs'] = sdevs
    data_df[keeper + '_skews'] = skews

  except requests.exceptions.Timeout:
    pass

  if len(save_data) == len(keepers):
    done = True

data_df.to_csv(dataFILE)

with open(outFILE, 'w') as fo:
  fo.write('stationID,x,y,slope_means,mean,slope_sdevs,sdev,slope_skews,skew\n')
  for elem in save_data:
    fo.write(','.join([e for e in elem]) + '\n')
# Out:
# 85.3788760353207
# 93.49031418988295
# 95.995619138887
# 96.66643849681704
# 87.12437538503663
# 92.14867547402287
# 77.02785953864057
# 89.97193510849476
# 90.11568211376549
# 97.9738517352317
# 95.20158806215346
# 93.55876514477377
# 92.81264973646383
# 79.70429187487166
# 81.73728523512904
# 95.35218016291327
# 95.35218016291327
# 90.69751523033747
# 92.75788897255117
# 97.98069683072079
# 97.45362447806147
# 74.39934287083305
# 23.033746320761175
# 96.02299952084331
# 92.29242247929359
# 90.48531727017591
# 92.10760490108837
# 92.5936066808132
# 96.01615442535424
# 95.05099596139365
# 77.82873571086316
# 96.48162091861181
# 95.29741939900062
# 86.15921692107605
# 97.98069683072079
# 9.028680950099254
# 96.2968033404066
# 97.76849887055924
# 86.53569717297557
# 9.172427955369978
# 21.712642891368333
# 97.15244027654187
# 95.20158806215346
# 26.01820795400096
# 14.456841672941337
# 93.23020056129782
# 15.155041412827707
# 79.49209391471011
# 96.23519748100486
# 95.41378602231501
# 92.57307139434594
# 70.70299130672872
# 91.23143267848587
# 97.98069683072079
# 92.03230885070846
# 95.92032308850709
# 84.85180368266137
# 89.97878020398385
# 96.63221301937162
# 65.26114039290847
# 93.23020056129782
# 89.12314326784858
# 90.54007803408858
# 41.05003764802519
# 95.39325073584777
# 97.30303237730166
# 95.36587035389144
# 65.3706619207338
# 93.55192004928469
# 95.74235060579095
# 91.51892668902731
# 93.17543979738517
# 97.80956944349374
# 97.41255390512697
# 31.87076459716613
# 96.44055034567732
# 94.67451570949414
# 83.35957286604147
# 94.3870216989527
# 85.20774864809364
# 96.88548155246765
# 94.05161201998767
# 94.98254500650283
# 91.01923471832431
# 19.25525361078787
# 92.36087343418441
# 95.50961735916216
# 85.50208775412416
# 97.90540078034088
# 97.37148333219248
# 95.01677048394825
# 66.84920254637552
# 90.40317612430694
# 90.2252036415908
# 51.26976521322473
# 87.30234786775274
# 89.19843931822848
# 79.21144499965774
# 93.42186323499213
# 95.92716818399617
# 96.81018550208775
# 90.78650147169553
# 97.29618728181258
# 95.03730577041549
# 87.76781436101034
# 82.6682182216442
# 57.39612567595318
# 95.48223697720584
# 49.15463070709836
# 26.326237251009655
# 88.8493394482853
# 97.69320282017934
# 80.69683072078855
# 85.76220138270929
# 95.71497022383463
# 72.07201040454514
# 94.17482373879116
# 94.9620097200356
# 92.22397152440277
# 95.82449175165993
# 88.87671983024164
# 92.81264973646383
# 85.91963857895819
# 5.079060852898898
# 46.53295913477993
# 88.86302963926347
# 97.15244027654187
# 93.9694708741187
# 93.88048463276063
# 76.03532069272366
# 89.19159422273941
# 81.34026969676226
# 94.18851392976933
# 93.5108494763502
# 92.20343623793552
# 94.29119036210555
# 97.82325963447191
# 87.50770073242522
# 77.397494695051
# 97.330412759258
# 91.66951878978712
# 95.495927168184
# 91.77904031761243
# 92.86741050037648
# 94.3117256485728
# 91.50523649804914
# 97.50154014648504
# 93.31234170716681
# 89.50646861523718
# 95.45485659524951
# 95.31795468546787
# 80.08761722226025
# 97.63844205626668
# 82.2848928742556
# 97.69320282017934
# 95.63282907796564
# 95.44801149976043
# 91.58737764391813
# 90.58799370251215
# 97.29618728181258
# 93.29180642069956
# 96.28311314942843
# 95.90663289752892
# 91.81326579505784
# 92.01177356424122
# 96.8649462660004
# 96.85810117051132
# 94.09268259292217
# 75.32343076185913
# 90.95078376343349
# 7.084673831199945
# 80.3751112328017
# 97.89171058936273
# 95.66020945992196
# 24.10842631254706
# 95.42063111780409
# 96.26942295845026
# 93.55192004928469
# 91.88171674994867
# 97.37148333219248
# 87.26127729481826
# 94.33910603052912
# 96.72119926072969
# 97.72058320213567
# 93.12067903347253
# 93.1275241289616
# 91.5599972619618
# 82.42863987952632
# 90.62221917995757
# 97.8985556848518
# 80.3340406598672
# 96.70750906975152
# 93.23020056129782
# 85.988089533849
# 92.69628311314942
# 80.30666027791088
# 95.89294270655076
# 89.12314326784858
# 88.1306044219317
# 86.54254226846464
# 93.40132794852488
# 83.0104729960983
# 95.77657608323636
# 97.44677938257239
# 81.6003833253474
# 63.4198097063454
# 33.465671846122255
# 91.70374426723252
# 16.87316038058731
# 75.56985419946608
# 94.85248819221029
# 93.83941405982613
# 95.495927168184
# 92.49093024847697
# 91.48470121158189
# 91.49839140256006
# 94.08583749743309
# 94.48285303579985
# 81.30604421931686
# 95.5712232185639
# 97.51523033746321
# 79.45102334177562
# 97.34410295023615
# 95.43432130878226
# 75.97371483332192
# 97.0223834622493
# 94.79088233280855
# 81.47032651105482
# 95.96823875693066
# 95.66020945992196
# 95.96823875693066
# 91.84064617701418
# 93.03169279211446
# 93.15490451091793
# 94.95516462454651
# 95.35902525840235
# 89.9993154904511
# 95.85871722910535
# 92.90848107331098
# 90.98500924087891
# 97.67951262920118
# 97.29618728181258
# 96.26942295845026
# 94.16797864330208
# 96.46793072763366
# 94.56499418166884
# 87.99370251215004
# 95.53699774111848
# 72.11308097747964
# 97.90540078034088
# 96.96762269833664
# 97.00869327127113
# 67.93072763365049
# 95.66020945992196
# 86.49462660004107
# 96.02299952084331
# 90.05407625436375
# 84.10568827435144
# 96.94708741186939
# 91.3683345882675
# 95.02361557943733
# 93.02484769662537
# 97.62475186528852
# 95.95454856595249
# 93.78465329591347
# 82.75720446300225
# 75.13176808816483
# 94.09268259292217
# 90.82072694914093
# 68.75898418782941
# 89.82818810322404
# 83.09261414196727
# 70.83304812102129
# 97.63844205626668
# 90.82757204463002
# 94.57183927715792
# 95.42063111780409
# 91.13560134163872
# 95.35218016291327
# 94.88671366965569
# 50.87959477034705
# 89.26689027311932
# 75.1043877062085
# 72.14046135943596
# 92.64836744472585
# 94.74296666438497
# 91.34779930180026
# 37.230474365117395
# 95.7628858922582
# 54.7539188171675
# 39.31822848928743
# 91.45047573413649
# 38.147717160654395
# 53.309603668971185
# 39.31822848928743
# 52.926278321582586
# 94.85933328769937
# 96.8649462660004
# 39.126565815593125
# 89.30111575056472
# 94.48969813128893
# 97.91909097131905
# 92.01177356424122
# 55.554794989390096
# 91.19720720104046
# 95.59175850503114
# USC00020949
# USC00021248
# USC00021314
# USC00022754
# USC00023393
# USC00023448
# USC00024829
# USC00025270
# USC00025418
# USC00025467
# USC00026132
# USC00026468
# USC00026601
# USC00026616
# USC00026716
# USC00026796
# USC00027390
# USC00027716
# USC00027855
# USC00028012
# USC00028162
# USC00028329
# USC00028396
# USC00028619
# USC00029156
# USC00029158
# USC00029542
# USC00029634
# USC00264950
# USC00267369
# USC00290041
# USC00290600
# USC00291664
# USC00291813
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00292030
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00292510
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00292608
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00292785
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00292837
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00293296
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00293649
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00294009
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00294398
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00294742
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00295084
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00295150
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00295617
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00296275
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00296619
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00296687
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00297008
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00297226
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00297340
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00297867
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00298535
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00299156
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00299820
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00420086
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00420730
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00420738
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00420788
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00420819
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00420849
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00421144
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00421171
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00421214
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00421308
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00421446
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00422057
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00422101
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00422385
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00422578
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USC00422592
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# ...
#   data_df[keeper + '_skews'] = skews
# USW00023081
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USW00023153
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USW00023154
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USW00023160
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USW00023162
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USW00023169
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USW00023183
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USW00023184
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USW00023185
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USW00023194
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USW00024121
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USW00024127
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USW00024128
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USW00093026
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
# USW00093129
# <ipython-input-4-75588c489f15>:172: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_means'] = means
# <ipython-input-4-75588c489f15>:173: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_sdevs'] = sdevs
# <ipython-input-4-75588c489f15>:174: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_df[keeper + '_skews'] = skews
